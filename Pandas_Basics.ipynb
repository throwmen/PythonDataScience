# %% [markdown]
# <a href="https://colab.research.google.com/github/throwmen/PythonDataScience/blob/main/Pandas_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Creating a datagrame from array

# %% [markdown]
# ## Option 1

# %%
# creating an array
data = np.array([[1, 4], [2, 5], [3, 6]])
data
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
# creating a dataframe
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'], columns=['col1', 'col2'])

# %%
# showing the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# ## Option 2

# %%
# creating an array with list shape
data = [[1, 4], [2, 5], [3, 6]]
data
# Out:
# [[1, 4], [2, 5], [3, 6]]

# %%
# creating a dataframe
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'], columns=['col1', 'col2'])

# %%
# showing the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# # Creating a DataFrame from a dictionary

# %%
# lists used for this example
states = ['California', 'Texas', 'Florida', 'New York']
population = [39613493, 29730311, 21944577, 19299981]

# %%
# Storing lists within a dictionary
dict_states = {'States': states, 'Population': population}

# %%
# Creating the dataframe
df_population = pd.DataFrame(dict_states)

# %%
df_population
# Out:
#        States  Population
# 0  California    39613493
# 1       Texas    29730311
# 2     Florida    21944577
# 3    New York    19299981

# %% [markdown]
# # Creating a DataFrame from a csv file

# %%
# reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
# show first 5 rows in a dataframe
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# show las 5 rows in a dataframe
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# show last n rows in a dataframe
df_exams.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# 991               completed          65             82             78
# 992                    none          55             76             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# getting access to the shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
# display n rows
pd.set_option('display.max_rows', 10)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # Attributes

# %%
# getting access to the shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
# getting access to the index attribute
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# getting access to the column attribute
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# data types of each column
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# # Methods

# %%
# showing the first 5 columns
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# showing the info of the dataframe
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# describing basic statistics of the dataframe
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# # Functions

# %%
# obtaining the length of the datagrame (number of rows)
len(df_exams)
# Out:
# 1000

# %%
# obtaining the highest index of the dataframe
max(df_exams.index)
# Out:
# 999

# %%
# obtaining the lowest index of the dataframe
min(df_exams.index)
# Out:
# 0

# %%
# obtaining the data type
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
# rounding the values of the dataset
round(df_exams, 2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # Selecting one column

# %% [markdown]
# ## Syntax 1

# %%
# select a column with [] (preferred way to select a column)
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# check out the data type of a column
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
# series: attributes and methods
df_exams['gender'].index
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %% [markdown]
# ## Syntax 2

# %%
# select a column with .
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# select a column with . (pitfalls)
df_exams.math score
# Out:
#   File "/tmp/ipython-input-3061062658.py", line 2
#     df_exams.math score
#                   ^
# SyntaxError: invalid syntax

# %%
# select the same column using []
df_exams['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %% [markdown]
# # Selecting two or more columns

# %%
# select 2 columns using [[]]
df_exams[['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
# check out the data type of the selection
type(df_exams[['gender', 'math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
# select 2 or more columns using [[]]
df_exams[['gender', 'writing score', 'math score', 'reading score']]
# Out:
#      gender  writing score  math score  reading score
# 0    female             74          72             72
# 1    female             88          69             90
# 2    female             93          90             95
# 3      male             44          47             57
# 4      male             75          76             78
# ..      ...            ...         ...            ...
# 995  female             95          88             99
# 996    male             55          62             55
# 997  female             65          59             71
# 998  female             77          68             78
# 999  female             86          77             86
#
# [1000 rows x 4 columns]

# %%
# we can't select 2 or more columns with the "."
df_exams.'gender', 'math score'
# Out:
#   File "/tmp/ipython-input-636409209.py", line 2
#     df_exams.'gender', 'math score'
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Adding a new column

# %% [markdown]
# ## Adding a new column with a scalar value

# %%
# adding a new column to dataframe
df_exams['language score'] = 70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                70
# 1                70
# 2                70
# 3                70
# 4                70
# ..              ...
# 995              70
# 996              70
# 997              70
# 998              70
# 999              70
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## Adding a new column with an array
#
# The dataframe has 1000 rows, so we need to create an array with 1000 elements

# %%
# import numpy
import numpy as np

# %%
# create an array of 1000 elements
language_score = np.arange(0, 1000)

# %%
# length of the array
len(language_score)
# Out:
# 1000

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ..              ...
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
# create random integer numbers between 1 and 100
int_language_score = np.random.randint(1, 100, size = 1000)

# %%
# min value inclusive and high value exclusive
min(int_language_score)
max(int_language_score)
# Out:
# np.int64(99)

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                86
# 1                31
# 2                79
# 3                56
# 4                69
# ..              ...
# 995              65
# 996              48
# 997              72
# 998               9
# 999              30
#
# [1000 rows x 9 columns]

# %%
# create random float numbers between 1 and 100
np.random.uniform(1, 100, size = 1000)
# Out:
# array([78.21451264, 92.10231757, 17.65997809, 88.95174603, 96.78221912,
#        21.56705017, 66.7617287 , 94.96832504, 13.7655155 , 85.34899037,
#        34.39907899, 39.96846534, 69.23770331, 63.45756292, 46.09006506,
#        84.63069146, 66.46199904, 55.08355674, 50.64647212, 32.11868806,
#        48.23712291, 49.34259873, 33.17148497, 38.46758245, 30.15428089,
#        11.04949412, 81.27547188, 68.46847843, 62.18192214,  1.07594183,
#        53.60352304, 66.12323753, 29.71306129, 56.54187467, 70.44194839,
#        31.52050632, 21.74376581, 36.62784059, 87.86644732, 12.01577256,
#        58.47481321, 42.7984344 , 68.53221133, 74.81282492,  5.3514388 ,
#        71.72276189, 89.19316885, 17.56476675,  3.91148799,  6.69578013,
#        75.86088028, 24.86420561, 35.29127432, 33.50572556, 45.06809875,
#        55.64531905, 98.10841567, 76.12601291, 82.15580207, 90.55755681,
#        89.38502741, 46.11409506, 56.27295628, 65.90535443, 41.92349241,
#        61.29209884, 76.06884881, 94.55032509, 14.05700857, 47.60795784,
#        36.85867273, 23.72184431, 33.16141147, 13.96402468, 86.63709887,
#        13.123067  , 15.54433677, 87.92239752, 23.82075636, 76.22307183,
#        58.57075377, 47.1374365 ,  6.19176483, 55.39815836, 78.68183957,
#        32.75608495, 85.50743313, 85.52113212, 82.1028349 , 69.04641161,
#        68.93156748, 29.3267831 , 86.0873168 , 85.21113049, 35.01187068,
#        13.35062773,  3.31419721, 13.72720008, 74.10036127, 44.38768781,
#        94.73699183, 18.93106346, 46.93512784, 40.94594178, 21.80681593,
#        14.37363003, 20.40899347,  8.56374132, 59.28276494, 63.38798335,
#         3.60165234, 67.60870453, 70.64481801, 10.09470771, 66.92590878,
#        44.16331193, 19.79521607, 96.29931181, 14.07290586, 84.27319424,
#         6.25069983, 87.81832586, 87.49479391, 29.66892476, 43.31094796,
#        49.06692744, 97.93829054, 80.42176346, 10.07472961, 44.84927936,
#        90.51510529, 76.52923348, 84.15234439, 13.12887307, 22.68246975,
#        21.23627807,  9.86738871, 97.20855118, 74.877001  ,  8.33626113,
#        71.46697894, 26.07817002, 52.76307345, 89.79594144,  9.14798617,
#        50.32590568, 58.23354814, 72.44133474, 51.12941802,  7.76254947,
#        31.31646319, 52.32765937, 99.80006129, 18.38438979,  4.97777176,
#        91.57783235, 37.25575992, 58.08800492, 91.1220602 , 83.83828934,
#        36.5088719 , 69.89370996, 20.07486977, 28.61430748, 40.27756178,
#        84.32437183, 84.85766274, 87.3793238 , 90.49054992, 93.34246401,
#        70.26250703, 95.67934741, 32.23839624, 88.31356873, 94.25911524])

# %% [markdown]
# # Adding a neww column

# %% [markdown]
# ## assign()
#
# when to use assign?
# - Add multiple columns in a single line of code
# - when you need to overwrite the values of an existing columns (best practice)
#
# It returns a new object (a copy) with all the original columns in addition to the new ones

# %%
# create random numbers for our new score columns
score1 = np.random.randint(1, 100, size = 1000)
score2 = np.random.randint(1, 100, size = 1000)

# %%
# create a series using the random numbers
series1 = pd.Series(score1)
series2 = pd.Series(score2)

# %%
# using assign() to add multiple columns
df_exams = df_exams.assign(score1=series1, score2=series2)

# %%
# show dataframe
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                86      33      94
# 1                31      12      81
# 2                79      39      11
# 3                56      80      16
# 4                69      10      42
# ..              ...     ...     ...
# 995              65      89      73
# 996              48      69      59
# 997              72      69      41
# 998               9      70      62
# 999              30      50      59
#
# [1000 rows x 11 columns]

# %% [markdown]
# ## insert()
#
# Inserts a new column at a specific position or index

# %%
# using index() to add a column at a specific position
df_exams.insert(1, 'test', series1)

# %%
# show dataframe
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    33        group B           bachelor's degree      standard
# 1    female    12        group C                some college      standard
# 2    female    39        group B             master's degree      standard
# 3      male    80        group A          associate's degree  free/reduced
# 4      male    10        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    89        group E             master's degree      standard
# 996    male    69        group C                 high school  free/reduced
# 997  female    69        group C                 high school  free/reduced
# 998  female    70        group D                some college      standard
# 999  female    50        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                86      33      94
# 1                31      12      81
# 2                79      39      11
# 3                56      80      16
# 4                69      10      42
# ..              ...     ...     ...
# 995              65      89      73
# 996              48      69      59
# 997              72      69      41
# 998               9      70      62
# 999              30      50      59
#
# [1000 rows x 12 columns]

# %% [markdown]
# # Math Operations

# %% [markdown]
# ## Operations in columns

# %%
# select a column and calculate total sum
df_exams['math score'].sum()
# Out:
# np.int64(66089)

# %%
# count, mean, std, max, and min
df_exams['math score'].count()
df_exams['math score'].mean()
df_exams['math score'].std()
df_exams['math score'].max()
df_exams['math score'].min()
# Out:
# 0

# %%
# easier calculation with .describe()
df_exams.describe()
# Out:
#               test  math score  reading score  writing score  language score  \
# count  1000.000000  1000.00000    1000.000000    1000.000000     1000.000000
# mean     50.270000    66.08900      69.169000      68.054000       51.044000
# std      28.169711    15.16308      14.600192      15.195657       27.827944
# min       1.000000     0.00000      17.000000      10.000000        1.000000
# 25%      26.000000    57.00000      59.000000      57.750000       27.000000
# 50%      51.000000    66.00000      70.000000      69.000000       52.000000
# 75%      74.000000    77.00000      79.000000      79.000000       74.000000
# max      99.000000   100.00000     100.000000     100.000000       99.000000
#
#             score1       score2
# count  1000.000000  1000.000000
# mean     50.270000    49.554000
# std      28.169711    28.340011
# min       1.000000     1.000000
# 25%      26.000000    24.000000
# 50%      51.000000    51.000000
# 75%      74.000000    73.000000
# max      99.000000    99.000000

# %% [markdown]
# ## Operations in rows

# %%
# calculating the sum in a row
df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
# calculating the average score and assigning the result to a new column
df_exams['average'] = (df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']) / 3

# %%
# showing the dataframe
df_exams.round(2)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    33        group B           bachelor's degree      standard
# 1    female    12        group C                some college      standard
# 2    female    39        group B             master's degree      standard
# 3      male    80        group A          associate's degree  free/reduced
# 4      male    10        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    89        group E             master's degree      standard
# 996    male    69        group C                 high school  free/reduced
# 997  female    69        group C                 high school  free/reduced
# 998  female    70        group D                some college      standard
# 999  female    50        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2  average
# 0                86      33      94    72.67
# 1                31      12      81    82.33
# 2                79      39      11    92.67
# 3                56      80      16    49.33
# 4                69      10      42    76.33
# ..              ...     ...     ...      ...
# 995              65      89      73    94.00
# 996              48      69      59    57.33
# 997              72      69      41    65.00
# 998               9      70      62    74.33
# 999              30      50      59    83.00
#
# [1000 rows x 13 columns]

# %% [markdown]
# # Value Counts

# %%
# counting gender elements

# len function
len(df_exams['gender'])
# .count() method
df_exams['gender'].count()
# Out:
# np.int64(1000)

# %%
# counter gender elements by category
df_exams['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
# return the relative frequency (divide all values by the sum of values)
df_exams['gender'].value_counts(normalize=True)
# Out:
# gender
# female    0.518
# male      0.482
# Name: proportion, dtype: float64

# %%
# counting "parental level of education" elements by category
df_exams['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
# return the relative frequency and round to 2 decimals
df_exams['parental level of education'].value_counts(normalize=True).round(2)
# Out:
# parental level of education
# some college          0.23
# associate's degree    0.22
# high school           0.20
# some high school      0.18
# bachelor's degree     0.12
# master's degree       0.06
# Name: proportion, dtype: float64

# %% [markdown]
# # Sort a dataframe

# %%
# sort by one column
df_exams.sort_values(by = 'math score')
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 59   female    57        group C            some high school  free/reduced
# 980  female    65        group B                 high school  free/reduced
# 17   female    81        group B            some high school  free/reduced
# 787  female    94        group B                some college      standard
# 145  female    59        group C                some college  free/reduced
# ..      ...   ...            ...                         ...           ...
# 623    male    41        group A                some college      standard
# 625    male    76        group D                some college      standard
# 962  female    54        group E          associate's degree      standard
# 458  female    81        group E           bachelor's degree      standard
# 916    male    21        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 59                     none           0             17             10
# 980                    none           8             24             23
# 17                     none          18             32             28
# 787                    none          19             38             32
# 145                    none          22             39             33
# ..                      ...         ...            ...            ...
# 623               completed         100             96             86
# 625               completed         100             97             99
# 962                    none         100            100            100
# 458                    none         100            100            100
# 916               completed         100            100            100
#
#      language score  score1  score2     average
# 59               67      57      97    9.000000
# 980              29      65      35   18.333333
# 17               25      81       2   26.000000
# 787              51      94      73   29.666667
# 145              26      59       3   31.333333
# ..              ...     ...     ...         ...
# 623               1      41      58   94.000000
# 625              52      76       5   98.666667
# 962              22      54      93  100.000000
# 458               3      81      95  100.000000
# 916              26      21       7  100.000000
#
# [1000 rows x 13 columns]

# %%
# sort descending by one column
df_exams.sort_values('math score', ascending = False)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 451  female    50        group E                some college      standard
# 458  female    81        group E           bachelor's degree      standard
# 962  female    54        group E          associate's degree      standard
# 149    male     9        group E          associate's degree  free/reduced
# 623    male    41        group A                some college      standard
# ..      ...   ...            ...                         ...           ...
# 145  female    59        group C                some college  free/reduced
# 787  female    94        group B                some college      standard
# 17   female    81        group B            some high school  free/reduced
# 980  female    65        group B                 high school  free/reduced
# 59   female    57        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 451                    none         100             92             97
# 458                    none         100            100            100
# 962                    none         100            100            100
# 149               completed         100            100             93
# 623               completed         100             96             86
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  score1  score2     average
# 451              69      50      11   96.333333
# 458               3      81      95  100.000000
# 962              22      54      93  100.000000
# 149              73       9      76   97.666667
# 623               1      41      58   94.000000
# ..              ...     ...     ...         ...
# 145              26      59       3   31.333333
# 787              51      94      73   29.666667
# 17               25      81       2   26.000000
# 980              29      65      35   18.333333
# 59               67      57      97    9.000000
#
# [1000 rows x 13 columns]

# %%
# sort descending by multiple columns
df_exams.sort_values('math score', ascending = False)
