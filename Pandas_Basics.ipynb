# %% [markdown]
# <a href="https://colab.research.google.com/github/throwmen/PythonDataScience/blob/main/Pandas_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Creating a datagrame from array

# %% [markdown]
# ## Option 1

# %%
# creating an array
data = np.array([[1, 4], [2, 5], [3, 6]])
data
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
# creating a dataframe
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'], columns=['col1', 'col2'])

# %%
# showing the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# ## Option 2

# %%
# creating an array with list shape
data = [[1, 4], [2, 5], [3, 6]]
data
# Out:
# [[1, 4], [2, 5], [3, 6]]

# %%
# creating a dataframe
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'], columns=['col1', 'col2'])

# %%
# showing the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# # Creating a DataFrame from a dictionary

# %%
# lists used for this example
states = ['California', 'Texas', 'Florida', 'New York']
population = [39613493, 29730311, 21944577, 19299981]

# %%
# Storing lists within a dictionary
dict_states = {'States': states, 'Population': population}

# %%
# Creating the dataframe
df_population = pd.DataFrame(dict_states)

# %%
df_population
# Out:
#        States  Population
# 0  California    39613493
# 1       Texas    29730311
# 2     Florida    21944577
# 3    New York    19299981

# %% [markdown]
# # Creating a DataFrame from a csv file

# %%
# reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
# show first 5 rows in a dataframe
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# show las 5 rows in a dataframe
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# show last n rows in a dataframe
df_exams.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# 991               completed          65             82             78
# 992                    none          55             76             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# getting access to the shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
# display n rows
pd.set_option('display.max_rows', 10)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # Attributes

# %%
# getting access to the shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
# getting access to the index attribute
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# getting access to the column attribute
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# data types of each column
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# # Methods

# %%
# showing the first 5 columns
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# showing the info of the dataframe
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# describing basic statistics of the dataframe
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# # Functions

# %%
# obtaining the length of the datagrame (number of rows)
len(df_exams)
# Out:
# 1000

# %%
# obtaining the highest index of the dataframe
max(df_exams.index)
# Out:
# 999

# %%
# obtaining the lowest index of the dataframe
min(df_exams.index)
# Out:
# 0

# %%
# obtaining the data type
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
# rounding the values of the dataset
round(df_exams, 2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # Selecting one column

# %% [markdown]
# ## Syntax 1

# %%
# select a column with [] (preferred way to select a column)
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# check out the data type of a column
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
# series: attributes and methods
df_exams['gender'].index
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %% [markdown]
# ## Syntax 2

# %%
# select a column with .
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# select a column with . (pitfalls)
df_exams.math score
# Out:
#   File "/tmp/ipython-input-3061062658.py", line 2
#     df_exams.math score
#                   ^
# SyntaxError: invalid syntax

# %%
# select the same column using []
df_exams['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %% [markdown]
# # Selecting two or more columns

# %%
# select 2 columns using [[]]
df_exams[['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
# check out the data type of the selection
type(df_exams[['gender', 'math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
# select 2 or more columns using [[]]
df_exams[['gender', 'writing score', 'math score', 'reading score']]
# Out:
#      gender  writing score  math score  reading score
# 0    female             74          72             72
# 1    female             88          69             90
# 2    female             93          90             95
# 3      male             44          47             57
# 4      male             75          76             78
# ..      ...            ...         ...            ...
# 995  female             95          88             99
# 996    male             55          62             55
# 997  female             65          59             71
# 998  female             77          68             78
# 999  female             86          77             86
#
# [1000 rows x 4 columns]

# %%
# we can't select 2 or more columns with the "."
df_exams.'gender', 'math score'
# Out:
#   File "/tmp/ipython-input-636409209.py", line 2
#     df_exams.'gender', 'math score'
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Adding a new column

# %% [markdown]
# ## Adding a new column with a scalar value

# %%
# adding a new column to dataframe
df_exams['language score'] = 70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                70
# 1                70
# 2                70
# 3                70
# 4                70
# ..              ...
# 995              70
# 996              70
# 997              70
# 998              70
# 999              70
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## Adding a new column with an array
#
# The dataframe has 1000 rows, so we need to create an array with 1000 elements

# %%
# import numpy
import numpy as np

# %%
# create an array of 1000 elements
language_score = np.arange(0, 1000)

# %%
# length of the array
len(language_score)
# Out:
# 1000

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ..              ...
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
# create random integer numbers between 1 and 100
int_language_score = np.random.randint(1, 100, size = 1000)

# %%
# min value inclusive and high value exclusive
min(int_language_score)
max(int_language_score)
# Out:
# np.int64(99)

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                82
# 1                69
# 2                64
# 3                84
# 4                13
# ..              ...
# 995              40
# 996               1
# 997              60
# 998              99
# 999              21
#
# [1000 rows x 9 columns]

# %%
# create random float numbers between 1 and 100
np.random.uniform(1, 100, size = 1000)
# Out:
# array([ 1.67747669,  1.03854308, 15.08099624, 26.42613314, 97.80344389,
#        38.64445404, 15.66056684,  9.0361631 ,  3.11572412,  7.51738165,
#        80.25787151, 65.84741196, 34.80174764, 72.48038845, 73.91782638,
#         4.44682475, 53.68581064, 45.50854321, 35.25557374, 10.9365287 ,
#        15.37714096, 51.50594573, 12.39301541, 54.48896049, 53.85558384,
#        55.18995141, 80.30523292, 41.10619421, 52.70331375,  7.17603347,
#        26.40889899, 43.57750245, 75.00071132, 82.62120292, 83.48131065,
#        91.32510151, 27.9011445 , 43.81258156, 42.89799242, 57.72627799,
#        34.09714146, 63.02063046, 87.54369275, 90.61511061,  9.42219633,
#        33.23081928,  5.79904742, 21.72396618, 97.45364888, 71.31837956,
#        43.58001017, 35.04805516, 74.06715655, 78.73806492, 18.29439976,
#        67.34399328, 69.88002822, 69.5787753 , 18.89937209, 16.282676  ,
#        61.19788791, 88.85668029, 39.04331552, 66.46324428, 48.73552916,
#        92.93694886, 17.50857621,  2.6138205 , 47.05308882, 58.4868868 ,
#        32.69178511, 13.15229579, 93.66513518, 85.30007189, 56.8102084 ,
#        48.52852592, 74.41740756, 25.90849633, 61.79732937, 55.08417201,
#        40.82535822, 12.91051488, 73.33339023, 73.36133958, 52.92145374,
#        79.64158281, 88.86360715, 84.33767834, 55.75489411, 72.05669476,
#        47.95761185, 61.79234138, 24.87062121, 29.76897682, 83.64326377,
#        30.44306642, 33.85079877, 59.41499981,  5.9171974 , 13.95156565,
#        38.18500403, 21.36644417, 48.4352475 , 82.59230992, 53.80490629,
#        46.42577129, 28.86604022, 26.92605124,  8.1011449 , 31.3575921 ,
#        71.26824002, 43.75587563, 38.79583817, 18.18751815, 22.54365818,
#        16.63447191, 16.62895348, 71.5032961 , 37.87245587, 58.83617145,
#        88.41014979, 85.05052488, 57.22928289, 38.28992577, 72.57104105,
#        44.00027791,  8.6607553 , 53.73060335, 26.34324826, 81.74172194,
#        68.67340382, 19.16323616, 45.73679487, 55.01438049, 80.69790735,
#        49.30536554, 43.17681466, 91.01824844, 20.07576142, 99.79383477,
#        56.22263125, 45.77076217, 15.03808973, 15.51856985, 23.42121236,
#         9.44038433, 65.03273189, 83.35142265, 75.29168023, 35.94683004,
#        30.52779874, 13.82531955, 68.82845683, 54.88533197, 61.77715608,
#        97.52447916, 52.42305988, 71.29026103, 99.85268007, 15.26656189,
#        80.48505297, 40.1065277 , 55.45479701, 98.96438202, 29.32657292,
#        54.44924283, 84.52633819, 55.93202899, 49.2037198 , 51.3209537 ,
#         9.53447596, 46.49773759, 48.33609259, 18.13020724, 27.26297035,
#        35.64181944, 96.6788364 ,  7.10467034, 87.71788793, 16.47236191,
#        62.70374042, 94.77640626, 80.50645771, 83.72728089, 10.18508377,
#        19.15652023, 27.03010545, 22.39520806, 64.42489802, 48.6094947 ,
#        58.98748078, 65.89662502, 42.18585774,  3.11914326, 48.00866222])

# %% [markdown]
# # Adding a neww column

# %% [markdown]
# ## assign()
#
# when to use assign?
# - Add multiple columns in a single line of code
# - when you need to overwrite the values of an existing columns (best practice)
#
# It returns a new object (a copy) with all the original columns in addition to the new ones

# %%
# create random numbers for our new score columns
score1 = np.random.randint(1, 100, size = 1000)
score2 = np.random.randint(1, 100, size = 1000)

# %%
# create a series using the random numbers
series1 = pd.Series(score1)
series2 = pd.Series(score2)

# %%
# using assign() to add multiple columns
df_exams = df_exams.assign(score1=series1, score2=series2)

# %%
# show dataframe
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                82      66      90
# 1                69      67      62
# 2                64      48      39
# 3                84      19      73
# 4                13      76      27
# ..              ...     ...     ...
# 995              40      84       4
# 996               1      80      60
# 997              60      19      63
# 998              99      84      34
# 999              21      68       4
#
# [1000 rows x 11 columns]

# %% [markdown]
# ## insert()
#
# Inserts a new column at a specific position or index

# %%
# using index() to add a column at a specific position
df_exams.insert(1, 'test', series1)

# %%
# show dataframe
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    66        group B           bachelor's degree      standard
# 1    female    67        group C                some college      standard
# 2    female    48        group B             master's degree      standard
# 3      male    19        group A          associate's degree  free/reduced
# 4      male    76        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    84        group E             master's degree      standard
# 996    male    80        group C                 high school  free/reduced
# 997  female    19        group C                 high school  free/reduced
# 998  female    84        group D                some college      standard
# 999  female    68        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                82      66      90
# 1                69      67      62
# 2                64      48      39
# 3                84      19      73
# 4                13      76      27
# ..              ...     ...     ...
# 995              40      84       4
# 996               1      80      60
# 997              60      19      63
# 998              99      84      34
# 999              21      68       4
#
# [1000 rows x 12 columns]

# %% [markdown]
# # Math Operations

# %% [markdown]
# ## Operations in columns

# %%
# select a column and calculate total sum
df_exams['math score'].sum()
# Out:
# np.int64(66089)

# %%
# count, mean, std, max, and min
df_exams['math score'].count()
df_exams['math score'].mean()
df_exams['math score'].std()
df_exams['math score'].max()
df_exams['math score'].min()
# Out:
# 0

# %%
# easier calculation with .describe()
df_exams.describe()
# Out:
#               test  math score  reading score  writing score  language score  \
# count  1000.000000  1000.00000    1000.000000    1000.000000     1000.000000
# mean     49.711000    66.08900      69.169000      68.054000       50.211000
# std      28.863967    15.16308      14.600192      15.195657       27.870616
# min       1.000000     0.00000      17.000000      10.000000        1.000000
# 25%      24.000000    57.00000      59.000000      57.750000       26.000000
# 50%      50.000000    66.00000      70.000000      69.000000       51.000000
# 75%      75.000000    77.00000      79.000000      79.000000       73.000000
# max      99.000000   100.00000     100.000000     100.000000       99.000000
#
#             score1       score2
# count  1000.000000  1000.000000
# mean     49.711000    48.834000
# std      28.863967    28.243409
# min       1.000000     1.000000
# 25%      24.000000    25.000000
# 50%      50.000000    48.000000
# 75%      75.000000    73.000000
# max      99.000000    99.000000

# %% [markdown]
# ## Operations in rows

# %%
# calculating the sum in a row
df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
# calculating the average score and assigning the result to a new column
df_exams['average'] = (df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']) / 3

# %%
# showing the dataframe
df_exams.round(2)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    66        group B           bachelor's degree      standard
# 1    female    67        group C                some college      standard
# 2    female    48        group B             master's degree      standard
# 3      male    19        group A          associate's degree  free/reduced
# 4      male    76        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    84        group E             master's degree      standard
# 996    male    80        group C                 high school  free/reduced
# 997  female    19        group C                 high school  free/reduced
# 998  female    84        group D                some college      standard
# 999  female    68        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2  average
# 0                82      66      90    72.67
# 1                69      67      62    82.33
# 2                64      48      39    92.67
# 3                84      19      73    49.33
# 4                13      76      27    76.33
# ..              ...     ...     ...      ...
# 995              40      84       4    94.00
# 996               1      80      60    57.33
# 997              60      19      63    65.00
# 998              99      84      34    74.33
# 999              21      68       4    83.00
#
# [1000 rows x 13 columns]

# %% [markdown]
# # Value Counts

# %%
# counting gender elements

# len function
len(df_exams['gender'])
# .count() method
df_exams['gender'].count()
# Out:
# np.int64(1000)

# %%
# counter gender elements by category
df_exams['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
# return the relative frequency (divide all values by the sum of values)
df_exams['gender'].value_counts(normalize=True)
# Out:
# gender
# female    0.518
# male      0.482
# Name: proportion, dtype: float64

# %%
# counting "parental level of education" elements by category
df_exams['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
# return the relative frequency and round to 2 decimals
df_exams['parental level of education'].value_counts(normalize=True).round(2)
# Out:
# parental level of education
# some college          0.23
# associate's degree    0.22
# high school           0.20
# some high school      0.18
# bachelor's degree     0.12
# master's degree       0.06
# Name: proportion, dtype: float64

# %% [markdown]
# # Sort a dataframe

# %%
# sort by one column
df_exams.sort_values(by = 'math score')
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 59   female    84        group C            some high school  free/reduced
# 980  female    49        group B                 high school  free/reduced
# 17   female     6        group B            some high school  free/reduced
# 787  female    63        group B                some college      standard
# 145  female    11        group C                some college  free/reduced
# ..      ...   ...            ...                         ...           ...
# 623    male    25        group A                some college      standard
# 625    male    87        group D                some college      standard
# 962  female    49        group E          associate's degree      standard
# 458  female    89        group E           bachelor's degree      standard
# 916    male    90        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 59                     none           0             17             10
# 980                    none           8             24             23
# 17                     none          18             32             28
# 787                    none          19             38             32
# 145                    none          22             39             33
# ..                      ...         ...            ...            ...
# 623               completed         100             96             86
# 625               completed         100             97             99
# 962                    none         100            100            100
# 458                    none         100            100            100
# 916               completed         100            100            100
#
#      language score  score1  score2     average
# 59               71      84       6    9.000000
# 980               6      49      38   18.333333
# 17               85       6      52   26.000000
# 787              67      63      84   29.666667
# 145              53      11      38   31.333333
# ..              ...     ...     ...         ...
# 623              86      25      52   94.000000
# 625              27      87      29   98.666667
# 962              49      49      17  100.000000
# 458              34      89      36  100.000000
# 916              31      90      37  100.000000
#
# [1000 rows x 13 columns]

# %%
# sort descending by one column
df_exams.sort_values('math score', ascending = False)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 451  female    10        group E                some college      standard
# 458  female    89        group E           bachelor's degree      standard
# 962  female    49        group E          associate's degree      standard
# 149    male    83        group E          associate's degree  free/reduced
# 623    male    25        group A                some college      standard
# ..      ...   ...            ...                         ...           ...
# 145  female    11        group C                some college  free/reduced
# 787  female    63        group B                some college      standard
# 17   female     6        group B            some high school  free/reduced
# 980  female    49        group B                 high school  free/reduced
# 59   female    84        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 451                    none         100             92             97
# 458                    none         100            100            100
# 962                    none         100            100            100
# 149               completed         100            100             93
# 623               completed         100             96             86
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  score1  score2     average
# 451              99      10      83   96.333333
# 458              34      89      36  100.000000
# 962              49      49      17  100.000000
# 149              63      83       5   97.666667
# 623              86      25      52   94.000000
# ..              ...     ...     ...         ...
# 145              53      11      38   31.333333
# 787              67      63      84   29.666667
# 17               85       6      52   26.000000
# 980               6      49      38   18.333333
# 59               71      84       6    9.000000
#
# [1000 rows x 13 columns]

# %%
# sort descending by multiple columns
df_exams.sort_values(['math score', 'reading score'], ascending = False)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 149    male    83        group E          associate's degree  free/reduced
# 458  female    89        group E           bachelor's degree      standard
# 916    male    90        group E           bachelor's degree      standard
# 962  female    49        group E          associate's degree      standard
# 625    male    87        group D                some college      standard
# ..      ...   ...            ...                         ...           ...
# 145  female    11        group C                some college  free/reduced
# 787  female    63        group B                some college      standard
# 17   female     6        group B            some high school  free/reduced
# 980  female    49        group B                 high school  free/reduced
# 59   female    84        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  score1  score2     average
# 149              63      83       5   97.666667
# 458              34      89      36  100.000000
# 916              31      90      37  100.000000
# 962              49      49      17  100.000000
# 625              27      87      29   98.666667
# ..              ...     ...     ...         ...
# 145              53      11      38   31.333333
# 787              67      63      84   29.666667
# 17               85       6      52   26.000000
# 980               6      49      38   18.333333
# 59               71      84       6    9.000000
#
# [1000 rows x 13 columns]

# %%
# sort descending by multiple columns and update dataframe
df_exams.sort_values(['math score', 'reading score'], ascending = False, inplace = True)

# %%
# sort descending with a key function
df_exams.sort_values('race/ethnicity', ascending=True, key=lambda col: col.str.lower())
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 741  female    40        group A          associate's degree  free/reduced
# 151    male     8        group A           bachelor's degree      standard
# 811    male    57        group A                 high school  free/reduced
# 112    male    95        group A          associate's degree      standard
# 25     male    63        group A             master's degree  free/reduced
# ..      ...   ...            ...                         ...           ...
# 751    male    18        group E                some college      standard
# 915  female    37        group E                some college      standard
# 592    male    54        group E           bachelor's degree      standard
# 479    male    14        group E          associate's degree      standard
# 517  female    44        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# 741                    none          37             57             56
# 151                    none          77             67             68
# 811                    none          45             47             49
# 112                    none          54             53             47
# 25                     none          73             74             72
# ..                      ...         ...            ...            ...
# 751                    none          68             72             65
# 915                    none          68             70             66
# 592                    none          68             68             64
# 479                    none          76             71             67
# 517               completed          66             74             73
#
#      language score  score1  score2    average
# 741              24      40      61  50.000000
# 151              36       8      25  70.666667
# 811              51      57      66  47.000000
# 112               6      95      97  51.333333
# 25               93      63      58  73.000000
# ..              ...     ...     ...        ...
# 751              27      18      42  68.333333
# 915               5      37       2  68.000000
# 592              23      54      18  66.666667
# 479              61      14      43  71.333333
# 517              55      44      46  71.000000
#
# [1000 rows x 13 columns]

# %% [markdown]
# # Create Index

# %%
import numpy as np
import random

# %%
# creating non repetitive values for the index
new_index = np.arange(0, 1000)

# %%
# shuffling the indexes
random.shuffle(new_index)

# %%
# create a new column with new index
df_exams['new_index'] = new_index
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 149    male    83        group E          associate's degree  free/reduced
# 458  female    89        group E           bachelor's degree      standard
# 916    male    90        group E           bachelor's degree      standard
# 962  female    49        group E          associate's degree      standard
# 625    male    87        group D                some college      standard
# ..      ...   ...            ...                         ...           ...
# 145  female    11        group C                some college  free/reduced
# 787  female    63        group B                some college      standard
# 17   female     6        group B            some high school  free/reduced
# 980  female    49        group B                 high school  free/reduced
# 59   female    84        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  score1  score2     average  new_index
# 149              63      83       5   97.666667        779
# 458              34      89      36  100.000000        943
# 916              31      90      37  100.000000        201
# 962              49      49      17  100.000000        254
# 625              27      87      29   98.666667        895
# ..              ...     ...     ...         ...        ...
# 145              53      11      38   31.333333         49
# 787              67      63      84   29.666667        471
# 17               85       6      52   26.000000        679
# 980               6      49      38   18.333333        506
# 59               71      84       6    9.000000        370
#
# [1000 rows x 14 columns]

# %% [markdown]
# # Set Index

# %%
# set new_index column as index
df_exams.set_index('new_index', inplace=True)
df_exams
# Out:
#            gender  test race/ethnicity parental level of education  \
# new_index
# 779          male    83        group E          associate's degree
# 943        female    89        group E           bachelor's degree
# 201          male    90        group E           bachelor's degree
# 254        female    49        group E          associate's degree
# 895          male    87        group D                some college
# ...           ...   ...            ...                         ...
# 49         female    11        group C                some college
# 471        female    63        group B                some college
# 679        female     6        group B            some high school
# 506        female    49        group B                 high school
# 370        female    84        group C            some high school
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# 779        free/reduced               completed         100            100
# 943            standard                    none         100            100
# 201            standard               completed         100            100
# 254            standard                    none         100            100
# 895            standard               completed         100             97
# ...                 ...                     ...         ...            ...
# 49         free/reduced                    none          22             39
# 471            standard                    none          19             38
# 679        free/reduced                    none          18             32
# 506        free/reduced                    none           8             24
# 370        free/reduced                    none           0             17
#
#            writing score  language score  score1  score2     average
# new_index
# 779                   93              63      83       5   97.666667
# 943                  100              34      89      36  100.000000
# 201                  100              31      90      37  100.000000
# 254                  100              49      49      17  100.000000
# 895                   99              27      87      29   98.666667
# ...                  ...             ...     ...     ...         ...
# 49                    33              53      11      38   31.333333
# 471                   32              67      63      84   29.666667
# 679                   28              85       6      52   26.000000
# 506                   23               6      49      38   18.333333
# 370                   10              71      84       6    9.000000
#
# [1000 rows x 13 columns]

# %%
# sort dataframe by new index
df_exams.sort_index(ascending=False, inplace=True)
df_exams
# Out:
#            gender  test race/ethnicity parental level of education  \
# new_index
# 999          male    20        group D                some college
# 998        female    16        group D                some college
# 997        female    70        group B                some college
# 996          male    89        group C                 high school
# 995          male    20        group B          associate's degree
# ...           ...   ...            ...                         ...
# 4          female    68        group D             master's degree
# 3          female    50        group D             master's degree
# 2          female    45        group C                 high school
# 1          female    80        group C                 high school
# 0          female    94        group C                 high school
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# 999        free/reduced               completed          69             60
# 998            standard               completed          69             79
# 997        free/reduced                    none          61             68
# 996            standard                    none          81             66
# 995            standard                    none          48             43
# ...                 ...                     ...         ...            ...
# 4          free/reduced                    none          40             59
# 3              standard                    none          78             91
# 2              standard                    none          61             72
# 1              standard                    none          72             80
# 0              standard                    none          72             80
#
#            writing score  language score  score1  score2    average
# new_index
# 999                   63              16      20       1  64.000000
# 998                   81              11      16      34  76.333333
# 997                   66              18      70      42  65.000000
# 996                   64              67      89      59  70.333333
# 995                   45              20      20      61  45.333333
# ...                  ...             ...     ...     ...        ...
# 4                     54              35      68      42  51.000000
# 3                     96              74      50      66  88.333333
# 2                     70              46      45      11  67.666667
# 1                     75              32      80      51  75.666667
# 0                     83              88      94      35  78.333333
#
# [1000 rows x 13 columns]

# %% [markdown]
# # Rename Column

# %%
# rename column and overwrite values of the dataframe
df_exams = df_exams.rename(columns={'gender':'Gender'})

# %%
 # rename multiple columns and update the dataframe with inplace argument
 df_exams.rename(columns={'math score': 'MS',
                          'reading score': 'RD',
                          'writing score': 'WS'}, inplace=True)

# %%
# show dataframe
df_exams
# Out:
#            Gender  test race/ethnicity parental level of education  \
# new_index
# 999          male    20        group D                some college
# 998        female    16        group D                some college
# 997        female    70        group B                some college
# 996          male    89        group C                 high school
# 995          male    20        group B          associate's degree
# ...           ...   ...            ...                         ...
# 4          female    68        group D             master's degree
# 3          female    50        group D             master's degree
# 2          female    45        group C                 high school
# 1          female    80        group C                 high school
# 0          female    94        group C                 high school
#
#                   lunch test preparation course  MS  RD  WS  language score  \
# new_index
# 999        free/reduced               completed  69  60  63              16
# 998            standard               completed  69  79  81              11
# 997        free/reduced                    none  61  68  66              18
# 996            standard                    none  81  66  64              67
# 995            standard                    none  48  43  45              20
# ...                 ...                     ...  ..  ..  ..             ...
# 4          free/reduced                    none  40  59  54              35
# 3              standard                    none  78  91  96              74
# 2              standard                    none  61  72  70              46
# 1              standard                    none  72  80  75              32
# 0              standard                    none  72  80  83              88
#
#            score1  score2    average
# new_index
# 999            20       1  64.000000
# 998            16      34  76.333333
# 997            70      42  65.000000
# 996            89      59  70.333333
# 995            20      61  45.333333
# ...           ...     ...        ...
# 4              68      42  51.000000
# 3              50      66  88.333333
# 2              45      11  67.666667
# 1              80      51  75.666667
# 0              94      35  78.333333
#
# [1000 rows x 13 columns]

# %% [markdown]
# # Rename Index

# %%
#rename index 0, 1 and 2 and update the dataframe
df_exams.rename(index={0:'A', 1:'B', 2:'C'}, inplace=True)
df_exams
# Out:
#            Gender  test race/ethnicity parental level of education  \
# new_index
# 999          male    20        group D                some college
# 998        female    16        group D                some college
# 997        female    70        group B                some college
# 996          male    89        group C                 high school
# 995          male    20        group B          associate's degree
# ...           ...   ...            ...                         ...
# 4          female    68        group D             master's degree
# 3          female    50        group D             master's degree
# C          female    45        group C                 high school
# B          female    80        group C                 high school
# A          female    94        group C                 high school
#
#                   lunch test preparation course  MS  RD  WS  language score  \
# new_index
# 999        free/reduced               completed  69  60  63              16
# 998            standard               completed  69  79  81              11
# 997        free/reduced                    none  61  68  66              18
# 996            standard                    none  81  66  64              67
# 995            standard                    none  48  43  45              20
# ...                 ...                     ...  ..  ..  ..             ...
# 4          free/reduced                    none  40  59  54              35
# 3              standard                    none  78  91  96              74
# C              standard                    none  61  72  70              46
# B              standard                    none  72  80  75              32
# A              standard                    none  72  80  83              88
#
#            score1  score2    average
# new_index
# 999            20       1  64.000000
# 998            16      34  76.333333
# 997            70      42  65.000000
# 996            89      59  70.333333
# 995            20      61  45.333333
# ...           ...     ...        ...
# 4              68      42  51.000000
# 3              50      66  88.333333
# C              45      11  67.666667
# B              80      51  75.666667
# A              94      35  78.333333
#
# [1000 rows x 13 columns]
