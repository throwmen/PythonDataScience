# %% [markdown]
# <a href="https://colab.research.google.com/github/throwmen/PythonDataScience/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello World

# %%
# printing my first message
print('Hello World')
# Out:
# Hello World

# %%
'Hello World'
# Out:
# 'Hello World'

# %%
# printing my name
print('Frank')
# Out:
# Frank

# %% [markdown]
# # Data Types

# %%
type(2.4)
# Out:
# float

# %%
+ 2
# Out:
# 2

# %%
4 - 1
# Out:
# 3

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type('Hello World')
# Out:
# str

# %%
print('Hello World'.upper())
print('Hello World'.lower())
print('Hello World'.title())
# Out:
# HELLO WORLD
# hello world
# Hello World

# %%
'Hello World'.count('l')
# Out:
# 3

# %%
'Hello World'.replace('o', 'u')
# Out:
# 'Hellu Wurld'

# %% [markdown]
# # Variables

# %%
message_1 = "I'm learning Python"
message_1
# Out:
# "I'm learning Python"

# %%
message_2 = "and it's fun"
message_2
# Out:
# "and it's fun"

# %%
message_1 + message_2
# Out:
# "I'm learning Pythonand it's fun"

# %%
message = message_1 + ' ' + message_2
message
# Out:
# "I'm learning Python and it's fun"

# %%
f'{message_1} {message_2}'
# Out:
# "I'm learning Python and it's fun"

# %% [markdown]
# # List

# %%
countries = ['United States', 'India', 'China', 'Brazil']
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
countries[0]
# Out:
# 'United States'

# %%
countries[-1]
# Out:
# 'Brazil'
