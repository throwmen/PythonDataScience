# %% [markdown]
# <a href="https://colab.research.google.com/github/throwmen/PythonDataScience/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fact(n : int) -> int:
  if(n == 0):
    return 1
  return n*fact(n-1)

fact(5)
# Out:
# 120
