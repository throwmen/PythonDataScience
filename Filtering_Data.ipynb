# %% [markdown]
# <a href="https://colab.research.google.com/github/throwmen/PythonDataScience/blob/main/Filtering_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_laptops = pd.read_csv('laptop_price.csv', encoding="latin-1")

# %%
df_laptops.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00

# %% [markdown]
# # Filter dataframe based on a condition

# %%
# find which rows have "Apple" in the "Company" column
df_laptops['Company'] == 'Apple'
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
# filter dataframe based on condition
df_laptops[df_laptops['Company'] == 'Apple']
# Out:
#       laptop_ID Company      Product   TypeName  Inches  \
# 0             1   Apple  MacBook Pro  Ultrabook    13.3
# 1             2   Apple  Macbook Air  Ultrabook    13.3
# 3             4   Apple  MacBook Pro  Ultrabook    15.4
# 4             5   Apple  MacBook Pro  Ultrabook    13.3
# 6             7   Apple  MacBook Pro  Ultrabook    15.4
# 7             8   Apple  Macbook Air  Ultrabook    13.3
# 12           13   Apple  MacBook Pro  Ultrabook    15.4
# 14           15   Apple  MacBook 12"  Ultrabook    12.0
# 15           16   Apple  MacBook Pro  Ultrabook    13.3
# 17           18   Apple  MacBook Pro  Ultrabook    15.4
# 26           27   Apple  MacBook Air  Ultrabook    13.3
# 34           35   Apple  MacBook Air  Ultrabook    13.3
# 45           46   Apple  MacBook Pro  Ultrabook    13.3
# 81           83   Apple  MacBook 12"  Ultrabook    12.0
# 249         254   Apple  MacBook Pro  Ultrabook    13.3
# 270         275   Apple  MacBook Pro  Ultrabook    13.3
# ...

# %%
# verify which companies are in the "Company" column with value_counts()
df_laptops[df_laptops['Company'] == 'Apple'].value_counts('Company')
# Out:
# Company
# Apple    21
# Name: count, dtype: int64

# %% [markdown]
# # Exercise 1

# %%
# find which rows don't have "HP" in the "Company" column
df_laptops[df_laptops['Company'] != 'HP']
# Out:
#       laptop_ID Company                                    Product  \
# 0             1   Apple                                MacBook Pro
# 1             2   Apple                                Macbook Air
# 3             4   Apple                                MacBook Pro
# 4             5   Apple                                MacBook Pro
# 5             6    Acer                                   Aspire 3
# ...         ...     ...                                        ...
# 1297       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298       1316  Lenovo                             Yoga 500-14ISK
# 1299       1317  Lenovo                             Yoga 900-13ISK
# 1300       1318  Lenovo                         IdeaPad 100S-14IBR
# 1302       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# # Exercise 2

# %%
df_laptops[df_laptops['Price_euros'] > 2000]
# Out:
#       laptop_ID Company        Product   TypeName  Inches  \
# 3             4   Apple    MacBook Pro  Ultrabook    15.4
# 6             7   Apple    MacBook Pro  Ultrabook    15.4
# 12           13   Apple    MacBook Pro  Ultrabook    15.4
# 17           18   Apple    MacBook Pro  Ultrabook    15.4
# 58           59     MSI     GS73VR 7RG     Gaming    17.3
# ...         ...     ...            ...        ...     ...
# 1203       1221    Dell         XPS 13  Ultrabook    13.3
# 1209       1227    Asus      Rog Strix     Gaming    15.6
# 1231       1249   Razer      Blade Pro     Gaming    14.0
# 1236       1254      HP  EliteBook 840  Ultrabook    14.0
# 1247       1265    Asus    Rog GL502VS     Gaming    15.6
#
#                         ScreenResolution                          Cpu   Ram  \
# 3     IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz  16GB
# 6     IPS Panel Retina Display 2880x1800         Intel Core i7 2.2GHz  16GB
# ...

# %% [markdown]
# # Create a column based on 1 conditions: np.where()

# %%
import numpy as np

# %%
# create an array based on price tiers

np.where (df_laptops['Price_euros'] > 2000, 'Expensive', 'Cheap')
# Out:
# array(['Cheap', 'Cheap', 'Cheap', ..., 'Cheap', 'Cheap', 'Cheap'],
#       dtype='<U9')

# %%
# set it to a new column
df_laptops['Price_tier'] = np.where (df_laptops['Price_euros'] > 2000, 'Expensive', 'Cheap')

# %%
# show first 5 rows
df_laptops.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
# count values in price_tier column
df_laptops['Price_tier'].value_counts()
# Out:
# Price_tier
# Cheap        1166
# Expensive     137
# Name: count, dtype: int64

# %% [markdown]
# # Exercise

# %%
# create an array based on cond(screen size > 15)
np.where(df_laptops['Inches'] > 15, 'Big', 'Small')
# Out:
# array(['Small', 'Small', 'Big', ..., 'Small', 'Big', 'Big'], dtype='<U5')

# %%
# set it to a new column
df_laptops['Screen_size'] = np.where(df_laptops['Inches'] > 15, 'Big', 'Small')

# %%
# show first 5 rows
df_laptops.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
# count values in screen_size column
df_laptops['Screen_size'].value_counts()
# Out:
# Screen_size
# Big      835
# Small    468
# Name: count, dtype: int64

# %% [markdown]
# # Filter dataframe based on a condition

# %%
# find Apple laptops
df_laptops['Company'] == 'Apple'
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
# find laptops that cost more than 2000 euros
df_laptops['Price_euros'] > 2000
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Price_euros, Length: 1303, dtype: bool

# %% [markdown]
# # Filter dataframe based on multiple conditions

# %%
# find Apple laptops that cost more than 2000 euros
(df_laptops['Price_euros'] > 2000) & (df_laptops['Company'] == 'Apple')
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %% [markdown]
# ## & (and)

# %%
# filter dataframe based on multiple conditions

df_laptops[(df_laptops['Price_euros'] > 2000) & (df_laptops['Company'] == 'Apple')]
# Out:
#      laptop_ID Company      Product   TypeName  Inches  \
# 3            4   Apple  MacBook Pro  Ultrabook    15.4
# 6            7   Apple  MacBook Pro  Ultrabook    15.4
# 12          13   Apple  MacBook Pro  Ultrabook    15.4
# 17          18   Apple  MacBook Pro  Ultrabook    15.4
# 249        254   Apple  MacBook Pro  Ultrabook    13.3
#
#                        ScreenResolution                   Cpu   Ram  \
# 3    IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16GB
# 6    IPS Panel Retina Display 2880x1800  Intel Core i7 2.2GHz  16GB
# 12   IPS Panel Retina Display 2880x1800  Intel Core i7 2.8GHz  16GB
# 17   IPS Panel Retina Display 2880x1800  Intel Core i7 2.9GHz  16GB
# 249  IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz   8GB
#
#                   Memory                           Gpu     OpSys  Weight  \
# 3              512GB SSD            AMD Radeon Pro 455     macOS  1.83kg
# 6    256GB Flash Storage       Intel Iris Pro Graphics  Mac OS X  2.04kg
# ...

# %% [markdown]
# ## | (or)

# %%
# find laptops Apple or Dell laptops
df_laptops[(df_laptops['Company']=='Apple') | (df_laptops['Price_euros'] > 2000)].value_counts('Company')
# Out:
# Company
# Dell         34
# Lenovo       32
# Apple        21
# HP           20
# MSI          19
# Asus         14
# Razer         5
# Acer          2
# Toshiba       2
# LG            2
# Google        1
# Microsoft     1
# Name: count, dtype: int64

# %%
# find laptops from Apple or Dell that cost over 2000 euros

df_laptops[((df_laptops['Company']=='Apple') | (df_laptops['Company']=='Dell')) & (df_laptops['Price_euros'] > 2000)].value_counts('Company')
# Out:
# Company
# Dell     34
# Apple     5
# Name: count, dtype: int64

# %% [markdown]
# # Creating a Conditional Column from More Than 2 Choices: np.select()

# %%
import numpy as np

# %%
# create an array based on multiple price tiers (+2 choices)

# create "conditions" and "values" variables
conditions = [
  df_laptops['Price_euros'] > 3000,
  (df_laptops['Price_euros'] > 2000) & (df_laptops['Price_euros'] <= 3000),
  (df_laptops['Price_euros'] > 800) & (df_laptops['Price_euros'] <= 2000),
  df_laptops['Price_euros'] <= 800
]

values = ['Too Expensive', 'Expensive', 'Affordable', 'Cheap']

# %%
# set it to a new column
df_laptops['Price_tiers'] = np.select(conditions, values, "default")

# %%
# show dataframe
df_laptops
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
# count values inside "price_tier" column
df_laptops['Price_tiers'].value_counts()
# Out:
# Price_tiers
# Affordable       655
# Cheap            511
# Expensive        118
# Too Expensive     19
# Name: count, dtype: int64

# %% [markdown]
# # Exercise

# %%
# create an array based on multiple screen size tiers (+2 choices)
# Too Big>16, Big>14, Small>12, Too Small<12
# create "conditions" amd "values" variables

conditions = [
    df_laptops['Inches'] > 16,
    (df_laptops['Inches'] > 14) & (df_laptops['Inches'] <= 16),
    (df_laptops['Inches'] > 12) & (df_laptops['Inches'] <= 14),
    df_laptops['Inches'] <= 12
]

values = ['Too Big', 'Big', 'Small', 'Too Small']

# %%
# set it to a new column
df_laptops['Screen_size'] = np.select(conditions, values, "default")

# %%
# show dataframe
df_laptops
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
# count values inside "screen_size" column
df_laptops['Screen_size'].value_counts()
# Out:
# Screen_size
# Big          674
# Small        419
# Too Big      166
# Too Small     44
# Name: count, dtype: int64

# %% [markdown]
# # isin(): Single Filtering

# %%
# select Apple or HP Laptops
df_laptops[df_laptops['Company'].isin(['Apple', 'HP'])]
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# 2             3      HP                               250 G6   Notebook
# 3             4   Apple                          MacBook Pro  Ultrabook
# 4             5   Apple                          MacBook Pro  Ultrabook
# ...         ...     ...                                  ...        ...
# 1282       1300      HP                     Stream 11-Y000na    Netbook
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                  Pavilion 15-AW003nv   Notebook
# 1296       1314      HP                     Stream 11-Y000na    Netbook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution  \
# 0       13.3  IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# isin() : Multiple Filtering

# %%
# find notebooks or ultrabooks from Apple or HP
filter1 = df_laptops['TypeName'].isin(['Notebook', 'Ultrabook'])
filter2 = df_laptops['Company'].isin(['Apple', 'HP'])

# %%
# filter dataframe
df_laptops[filter1 & filter2]
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# 2             3      HP                               250 G6   Notebook
# 3             4   Apple                          MacBook Pro  Ultrabook
# 4             5   Apple                          MacBook Pro  Ultrabook
# ...         ...     ...                                  ...        ...
# 1273       1291      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1280       1298      HP                  Pavilion 15-AW003nv   Notebook
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                  Pavilion 15-AW003nv   Notebook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution                         Cpu  \
# ...

# %% [markdown]
# # duplicated()

# %% [markdown]
# ## Example 1

# %%
# find duplicates in 1 column/series
df_laptops.duplicated('laptop_ID')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
# show elements in dataframe with duplicates in column 'laptop_ID'
df_laptops[df_laptops.duplicated('laptop_ID')]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros, Price_tier, Screen_size, Price_tiers]
# Index: []

# %%
# duplicates in 2 or more columns
df_laptops.duplicated(['Product', 'TypeName', 'Inches'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1298     True
# 1299     True
# 1300     True
# 1301     True
# 1302     True
# Length: 1303, dtype: bool

# %%
duplicated = df_laptops.duplicated(['Product', 'TypeName', 'Inches'])

# %%
# show all the values duplicated (except for the first - keep = 'first')
df_laptops[duplicated].sort_values(['Product', 'TypeName'])
# Out:
#       laptop_ID Company                              Product  \
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1098       1113      HP                               250 G5
# 1170       1188      HP                               250 G5
# 10           11      HP                               250 G6
# ...         ...     ...                                  ...
# 414         421    Asus                         ZenBook Flip
# 826         835    Asus                         ZenBook Flip
# 1275       1293    Asus                 ZenBook UX305CA-UBM1
# 1289       1307    Asus                 ZenBook UX305CA-UBM1
# 676         684    Asus                            Zenbook 3
#
#                 TypeName  Inches                           ScreenResolution  \
# 1287            Notebook    15.6                                   1366x768
# 1301            Notebook    15.6                                   1366x768
# ...
